# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity
import datetime
from sklearn.preprocessing import LabelEncoder

# %%
# Load the data
df = pd.read_csv('supermarket_data.csv')

# Pivot the data to create a user-item matrix
matrix = df.pivot_table(index='Product Name', columns='User ID', values='Interaction Type')
matrix.head()
# Out:
# User ID                                0    1    2    3         4    5    6   \
# Product Name
# 3-ring staple pack                    NaN  NaN  NaN  NaN       NaN  NaN  1.0
# 9-3/4 Diameter Round Wall Clock  0.000000  1.0  1.0  1.0  2.000000  2.0  NaN
# American Pencil                  2.333333  NaN  2.0  NaN  1.000000  0.0  0.0
# Avery 477                        2.000000  NaN  NaN  1.0  1.666667  NaN  NaN
# Avery Non-Stick Binders          3.000000  NaN  1.0  0.5       NaN  NaN  1.5
#
# User ID                           7    8    9   ...   90   91   92   93   94  \
# Product Name                                    ...
# 3-ring staple pack               NaN  NaN  NaN  ...  NaN  NaN  NaN  1.5  NaN
# 9-3/4 Diameter Round Wall Clock  NaN  3.0  2.5  ...  3.0  2.0  0.5  2.0  NaN
# American Pencil                  NaN  1.0  2.0  ...  NaN  2.5  NaN  2.0  2.0
# Avery 477                        1.0  NaN  0.0  ...  NaN  NaN  1.0  0.0  2.0
# Avery Non-Stick Binders          0.0  NaN  1.0  ...  3.0  1.5  NaN  NaN  2.0
#
# User ID                           95   96   97   98   99
# Product Name
# 3-ring staple pack               NaN  0.0  NaN  NaN  NaN
# 9-3/4 Diameter Round Wall Clock  NaN  NaN  NaN  1.0  NaN
# American Pencil                  NaN  3.0  1.0  1.5  NaN
# Avery 477                        NaN  NaN  NaN  0.0  NaN
# Avery Non-Stick Binders          1.0  1.0  0.0  1.0  1.5
#
# [5 rows x 100 columns]

# %%
# Normalize user-item matrix
matrix_norm = matrix.subtract(matrix.mean(axis=1), axis = 0)
matrix_norm.head()
# Out:
# User ID                                0         1         2         3   \
# Product Name
# 3-ring staple pack                    NaN       NaN       NaN       NaN
# 9-3/4 Diameter Round Wall Clock -1.383929 -0.383929 -0.383929 -0.383929
# American Pencil                  0.878571       NaN  0.545238       NaN
# Avery 477                        0.583333       NaN       NaN -0.416667
# Avery Non-Stick Binders          1.570312       NaN -0.429688 -0.929688
#
# User ID                                4         5         6         7   \
# Product Name
# 3-ring staple pack                    NaN       NaN -0.603030       NaN
# 9-3/4 Diameter Round Wall Clock  0.616071  0.616071       NaN       NaN
# American Pencil                 -0.454762 -1.454762 -1.454762       NaN
# Avery 477                        0.250000       NaN       NaN -0.416667
# Avery Non-Stick Binders               NaN       NaN  0.070312 -1.429688
#
# User ID                                8         9   ...        90        91  \
# Product Name                                         ...
# 3-ring staple pack                    NaN       NaN  ...       NaN       NaN
# 9-3/4 Diameter Round Wall Clock  1.616071  1.116071  ...  1.616071  0.616071
# American Pencil                 -0.454762  0.545238  ...       NaN  1.045238
# Avery 477                             NaN -1.416667  ...       NaN       NaN
# Avery Non-Stick Binders               NaN -0.429688  ...  1.570312  0.070312
#
# User ID                                92        93        94        95  \
# Product Name
# 3-ring staple pack                    NaN -0.103030       NaN       NaN
# 9-3/4 Diameter Round Wall Clock -0.883929  0.616071       NaN       NaN
# American Pencil                       NaN  0.545238  0.545238       NaN
# Avery 477                       -0.416667 -1.416667  0.583333       NaN
# Avery Non-Stick Binders               NaN       NaN  0.570312 -0.429688
#
# User ID                                96        97        98        99
# Product Name
# 3-ring staple pack              -1.603030       NaN       NaN       NaN
# 9-3/4 Diameter Round Wall Clock       NaN       NaN -0.383929       NaN
# American Pencil                  1.545238 -0.454762  0.045238       NaN
# Avery 477                             NaN       NaN -1.416667       NaN
# Avery Non-Stick Binders         -0.429688 -1.429688 -0.429688  0.070312
#
# [5 rows x 100 columns]

# %%
# Item similarity matrix using Pearson correlation
item_similarity = matrix_norm.T.corr()
item_similarity.head()
# Out:
# Product Name                     3-ring staple pack  \
# Product Name
# 3-ring staple pack                         1.000000
# 9-3/4 Diameter Round Wall Clock           -0.041222
# American Pencil                            0.058295
# Avery 477                                 -0.062426
# Avery Non-Stick Binders                   -0.265925
#
# Product Name                     9-3/4 Diameter Round Wall Clock  \
# Product Name
# 3-ring staple pack                                     -0.041222
# 9-3/4 Diameter Round Wall Clock                         1.000000
# American Pencil                                         0.071003
# Avery 477                                              -0.327610
# Avery Non-Stick Binders                                 0.382500
#
# Product Name                     American Pencil  Avery 477  \
# Product Name
# 3-ring staple pack                      0.058295  -0.062426
# 9-3/4 Diameter Round Wall Clock         0.071003  -0.327610
# American Pencil                         1.000000  -0.171252
# Avery 477                              -0.171252   1.000000
# Avery Non-Stick Binders                 0.018224   0.294632
#
# Product Name                     Avery Non-Stick Binders  \
# Product Name
# 3-ring staple pack                             -0.265925
# 9-3/4 Diameter Round Wall Clock                 0.382500
# American Pencil                                 0.018224
# Avery 477                                       0.294632
# Avery Non-Stick Binders                         1.000000
#
# Product Name                     Belkin 325VA UPS Surge Protector, 6'  \
# Product Name
# 3-ring staple pack                                          -0.055956
# 9-3/4 Diameter Round Wall Clock                              0.194598
# American Pencil                                              0.107681
# Avery 477                                                   -0.006621
# Avery Non-Stick Binders                                     -0.046882
#
# Product Name                     Belkin F9G930V10-GRY 9 Outlet Surge  \
# Product Name
# 3-ring staple pack                                          0.021850
# 9-3/4 Diameter Round Wall Clock                             0.202139
# American Pencil                                             0.219092
# Avery 477                                                  -0.249883
# Avery Non-Stick Binders                                     0.017157
#
# Product Name                     Bevis Round Conference Table Top, X-Base  \
# Product Name
# 3-ring staple pack                                               0.045183
# 9-3/4 Diameter Round Wall Clock                                 -0.170898
# American Pencil                                                  0.249481
# Avery 477                                                        0.015302
# Avery Non-Stick Binders                                         -0.047902
#
# Product Name                     Bevis Traditional Conference Table Top, Plinth Base  \
# Product Name
# 3-ring staple pack                                                        0.235360
# 9-3/4 Diameter Round Wall Clock                                           0.029635
# American Pencil                                                          -0.237776
# Avery 477                                                                -0.090521
# Avery Non-Stick Binders                                                  -0.233331
#
# Product Name                     Binding Machine Supplies  ...  \
# Product Name                                               ...
# 3-ring staple pack                               0.230521  ...
# 9-3/4 Diameter Round Wall Clock                  0.176432  ...
# American Pencil                                  0.073926  ...
# Avery 477                                        0.154010  ...
# Avery Non-Stick Binders                         -0.205497  ...
#
# Product Name                     Xblue XB-1670-86 X16 Small Office Telephone - Titanium  \
# Product Name
# 3-ring staple pack                                                        0.078696
# 9-3/4 Diameter Round Wall Clock                                          -0.175588
# American Pencil                                                          -0.513204
# Avery 477                                                                 0.091613
# Avery Non-Stick Binders                                                  -0.188529
#
# Product Name                     Xerox 1934  Xerox 1979  Xerox 1985  \
# Product Name
# 3-ring staple pack                -0.219516   -0.138750    0.008578
# 9-3/4 Diameter Round Wall Clock   -0.456468   -0.010051   -0.101544
# American Pencil                    0.243468   -0.255048    0.054038
# Avery 477                          0.321177   -0.070510   -0.490059
# Avery Non-Stick Binders            0.264739   -0.041105   -0.085070
#
# Product Name                     Xerox 1995   Xerox 2  Xerox 21  Xerox 224  \
# Product Name
# 3-ring staple pack                 0.162673  0.012005  0.146988  -0.085959
# 9-3/4 Diameter Round Wall Clock    0.282679  0.161065 -0.058200   0.023627
# American Pencil                    0.109329  0.121202 -0.125283  -0.143903
# Avery 477                         -0.192985  0.204967  0.106069  -0.052540
# Avery Non-Stick Binders            0.059119  0.164654 -0.108911  -0.040247
#
# Product Name                     XtraLife ClearVue Slant-D Ring Binder, White, 3"  \
# Product Name
# 3-ring staple pack                                                       0.273032
# 9-3/4 Diameter Round Wall Clock                                          0.012887
# American Pencil                                                          0.045226
# Avery 477                                                               -0.079876
# Avery Non-Stick Binders                                                  0.057874
#
# Product Name                     XtraLife ClearVue Slant-D Ring Binders by Cardinal
# Product Name
# 3-ring staple pack                                                       -0.031412
# 9-3/4 Diameter Round Wall Clock                                          -0.111152
# American Pencil                                                           0.112694
# Avery 477                                                                -0.272208
# Avery Non-Stick Binders                                                  -0.261846
#
# [5 rows x 89 columns]

# %%
# Item-based recommendation function
def item_based_rec(picked_userid=1, number_of_similar_items=5, number_of_recommendations =3):
  import operator
  # Products that the target user has not interact with
  picked_userid_unsee = pd.DataFrame(matrix_norm[picked_userid].isna()).reset_index()
  picked_userid_unsee = picked_userid_unsee[picked_userid_unsee[picked_userid]==True]['Product Name'].values.tolist()

  # Products that the target user has interact
  picked_userid_see = pd.DataFrame(matrix_norm[picked_userid].dropna(axis=0, how='all')\
                            .sort_values(ascending=False))\
                            .reset_index()\
                            .rename(columns={picked_userid:'Interaction Type'})
  
  # Dictionary to save the unsee product and predicted a interaction
  interaction_prediction ={}  

  # Loop through unsee products          
  for picked_item in picked_userid_unsee: 
    # Calculate the similarity score of the picked products with other products
    picked_product_similarity_score = item_similarity[[picked_item]].reset_index().rename(columns={picked_item:'similarity_score'})
    # Rank the similarities between the picked user see products and the unsee products.
    picked_userid_see_similarity = pd.merge(left=picked_userid_see, 
                                                right=picked_product_similarity_score, 
                                                on='Product Name', 
                                                how='inner')\
                                        .sort_values('similarity_score', ascending=False)[:number_of_similar_items]
    # Calculate the predicted interaction using weighted average of similarity scores and the interactions from user
    predicted_interaction = round(np.average(picked_userid_see_similarity["Interaction Type"], 
                                        weights=picked_userid_see_similarity['similarity_score']), 6)
    # Save the predicted interaction in the dictionary
    interaction_prediction[picked_item] = predicted_interaction
    # Return the top recommended products
  return sorted(interaction_prediction.items(), key=operator.itemgetter(1), reverse=True)[:number_of_recommendations]

# Get recommendations
recommended_product = item_based_rec(picked_userid=97, number_of_similar_items=10, number_of_recommendations =3)
print(recommended_product)
# Out:
# [('Case Logic 2.4GHz Wireless Keyboard', 0.519904), ('Hot File 7-Pocket, Floor Stand', 0.492073), ('Eldon 200 Class Desk Accessories, Burgundy', 0.364229)]
